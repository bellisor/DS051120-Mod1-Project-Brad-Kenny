# %%
import requests
import pandas as pd
import json

# %%
today = 2019 # 2020 is an outlier in terms of theater attendance, so we will not include
config_path = '/Users/koh/.secret/tmdb_creds.json'

def get_keys(path):
    with open(path) as f:
        return json.load(f)

config = get_keys(config_path)

def get_data_for_last_n_years(n_years, sort_by='popularity.desc'):
    ''' 
    collate top 200 movies data for the last n years 
    '''
    movies_array = []
    for i in range(n_years):
        primary_release_year = today - i
        
        # range(10) to produce top 200 movies (ie. 10 pages * 20 per page)       
        for j in range(10):
            page = j + 1
            query_params = {
                    'primary_release_year': primary_release_year, 
                    'sort_by': sort_by,
                    'page': page
                }  
            params = dict(list(config.items()) + list(query_params.items()))
            resp = requests.get('https://api.themoviedb.org/3/discover/movie', params=params)
            resp_json = resp.json()
            
            for k in resp_json['results']:
                movies_array.append(k)
                
    return movies_array

# %%
data = get_data_for_last_n_years(25, sort_by='revenue.desc')

# %%
df = pd.DataFrame(data)

# %%
df.sort_values(by=['popularity'], ascending=False)
# Out:
#       popularity  vote_count  video                       poster_path      id  \
# 42       522.654        3513  False  /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg  419704
# 18        97.875        5089  False  /iZf0KyrE25z1sage4SYFLCCrMi9.jpg  530915
# 27        92.150        7551  False  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg  496243
# 434       89.606        8281  False  /gajva2L0rPYkEWjzgFlBXCAVBE5.jpg  335984
# 5         88.810       12719  False  /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg  475557
# ...          ...         ...    ...                               ...     ...
# 4590       0.000           0  False                              None  709671
# 200        0.000           0  False  /oX1Kp08SFpgtsPeXzwCbSjbQUYl.jpg  709579
# 4973       0.000           0  False  /rPdYHmoVOD8iCPhQJ4VdvCHBcQM.jpg  709696
# 817        0.000           0  False  /sAvukY7lJ6tjBaPM37TNSYVAJhv.jpg  709918
# 1264       0.000           0  False  /hLPXYEedllTatjoi29pfj57ZgBy.jpg  707069
#
#       adult                     backdrop_path original_language  \
# 42    False  /5BwqwxMEjeFtdknRV792Svo0K1v.jpg                en
# 18    False  /2lBOQK06tltt8SQaswgb8d657Mv.jpg                en
# 27    False  /ApiBzeaa95TNYliSbQ8pJv4Fje7.jpg                ko
# 434   False  /sAtoMqDVhNDQBc3QJL3RF6hlhGq.jpg                en
# 5     False  /f5F4cRhQdUbyVbB5lTNCwUzD6BP.jpg                en
# ...     ...                               ...               ...
# 4590  False                              None                zh
# 200   False                              None                en
# 4973  False                              None                zh
# 817   False  /bBubM9chhBQ1FIeUEiFuZN5odYI.jpg                en
# 1264  False  /2LUEkV1aATgtNnKl3ecgwnSbsKb.jpg                en
#
#                            original_title  \
# 42                               Ad Astra
# 18                                   1917
# 27                                    기생충
# 434                     Blade Runner 2049
# 5                                   Joker
# ...                                   ...
# 4590                                   生产
# 200                Red Dead Redemption II
# 4973                                告别圆明园
# 817   Mad Max: Fury Road (Black & Chrome)
# 1264                    Beyond: Two Souls
#
#                                    genre_ids  \
# 42                                 [18, 878]
# 18                   [28, 18, 36, 53, 10752]
# 27                              [35, 18, 53]
# 434                                [18, 878]
# 5                               [80, 18, 53]
# ...                                      ...
# 4590                                      []
# 200                     [28, 12, 80, 18, 37]
# 4973                                    [99]
# 817                            [28, 12, 878]
# 1264  [28, 12, 18, 14, 9648, 10749, 878, 53]
#
#                                     title  vote_average  \
# 42                               Ad Astra           6.0
# 18                                   1917           7.9
# 27                               Parasite           8.5
# 434                     Blade Runner 2049           7.4
# 5                                   Joker           8.2
# ...                                   ...           ...
# 4590                           Production           0.0
# 200                Red Dead Redemption II           0.0
# 4973               Farewell, Yuanmingyuan           0.0
# 817   Mad Max: Fury Road (Black & Chrome)           0.0
# 1264                    Beyond: Two Souls           0.0
#
#                                                overview release_date
# 42    The near future, a time when both hope and har...   2019-09-17
# 18    At the height of the First World War, two youn...   2019-12-25
# 27    All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 434   Thirty years after the events of the first fil...   2017-10-04
# 5     During the 1980s, a failed stand-up comedian i...   2019-10-02
# ...                                                 ...          ...
# 4590  A series of images of Sichuan teahouses shot w...   1997-06-11
# 200   The year is 1899. The era of the Wild West is ...   2018-10-26
# 4973  SYNOPSIS  Towards the end of 1989, several art...   1995-06-20
# 817   An apocalyptic story set in the furthest reach...   2015-05-14
# 1264  Live the life of Jodie Holmes, a young woman w...   2013-10-08
#
# [5000 rows x 14 columns]

# %%
resp = requests.get('https://api.themoviedb.org/3/genre/movie/list', params=config)
resp_json = resp.json()
genre_list = resp_json['genres']

def genre_mapper(genres):
    '''
    finds genre name in genre list by id and returns list of genres
    '''
    genre_container = []
    if not genres:
        return None
    else:
        for genre in genres:
            for x in genre_list:
                if genre == x['id']:
                    genre_container.append(x['name'])
                    
    return genre_container

# %%
# replace genre ids with names
df['genre_mapped_ids'] = df.genre_ids.map(lambda x: genre_mapper(x))

# %%
df.head()
# Out:
# '1995-01-01'

# %%
# get fuller movie data

for i, gid in enumerate(df.id):
    resp = requests.get('https://api.themoviedb.org/3/movie/' + str(gid), params=config)
    resp_json = resp.json()
    
    # backfill column data for each movie
    df.at[i, 'revenue'] = resp_json.get('revenue')  
    df.at[i, 'runtime'] = resp_json.get('runtime') 
    df.at[i, 'vote_count'] = resp_json.get('vote_count') 
    df.at[i, 'vote_average'] = resp_json.get('vote_average')
    df.at[i, 'production_companies'] = resp_json.get('production_companies')

# %%
# for some reason Red Dead Redemption II was included in the results, so we'll want to remove it bc it's a video game
df = df[df.id != 709579]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4999 entries, 0 to 4999
# Data columns (total 18 columns):
# popularity              4999 non-null float64
# vote_count              4996 non-null float64
# video                   4999 non-null bool
# poster_path             4857 non-null object
# id                      4999 non-null int64
# adult                   4999 non-null bool
# backdrop_path           4404 non-null object
# original_language       4999 non-null object
# original_title          4999 non-null object
# genre_ids               4999 non-null object
# title                   4999 non-null object
# vote_average            4996 non-null float64
# overview                4999 non-null object
# release_date            4999 non-null object
# genre_mapped_ids        4929 non-null object
# revenue                 4996 non-null float64
# runtime                 4983 non-null float64
# production_companies    4996 non-null object
# dtypes: bool(2), float64(5), int64(1), object(10)
# memory usage: 673.7+ KB

# %%
df.to_pickle('movie_data.pkl')
