# %%
import requests
import pandas as pd
import json
import seaborn as sns
import matplotlib.pyplot as plt

# remove scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
today = 2019 # 2020 is an outlier in terms of theater attendance, so we will not include
config_path = '/Users/koh/.secret/tmdb_creds.json'

def get_keys(path):
    with open(path) as f:
        return json.load(f)

config = get_keys(config_path)

def get_data_for_last_n_years(n_years, sort_by='popularity.desc'):
    ''' 
    collate top 200 movies data for the last n years 
    '''
    movies_array = []
    for i in range(n_years):
        primary_release_year = today - i
        
        # range(10) to produce top 200 movies (ie. 10 pages * 20 per page)       
        for j in range(10):
            page = j + 1
            query_params = {
                    'primary_release_year': primary_release_year, 
                    'sort_by': sort_by,
                    'page': page
                }  
            params = dict(list(config.items()) + list(query_params.items()))
            resp = requests.get('https://api.themoviedb.org/3/discover/movie', params=params)
            resp_json = resp.json()
            
            for k in resp_json['results']:
                movies_array.append(k)
                
    return movies_array

# %%
data = get_data_for_last_n_years(5, sort_by='revenue.desc')

# %%
df = pd.DataFrame(data)

# %%
df.sort_values(by=['popularity'], ascending=False)
# Out:
#      popularity      id  video  vote_count  vote_average  \
# 42    588.55200  419704  False        3501       6.00000
# 18    106.05500  530915  False        5071       7.90000
# 5      93.56300  475557  False       12700       8.20000
# 6      90.64000  181812  False        4698       6.50000
# 27     85.67100  496243  False        7539       8.50000
# ..          ...     ...    ...         ...           ...
# 191     0.60000  639251  False           2       9.80000
# 991     0.60000  684290  False           0       0.00000
# 992     0.60000  582327  False           1       6.00000
# 194     0.60000  679106  False           0       0.00000
# 977     0.60000  546299  False           1       3.00000
#
#                                          title release_date original_language  \
# 42                                    Ad Astra   2019-09-17                en
# 18                                        1917   2019-12-25                en
# 5                                        Joker   2019-10-02                en
# 6             Star Wars: The Rise of Skywalker   2019-12-18                en
# 27                                    Parasite   2019-05-30                ko
# ..                                         ...          ...               ...
# 191               Kral Şakir: Korsanlar Diyarı   2019-10-04                tr
# 991  Happy Little Submarine: Magic Box of Time   2015-05-29                zh
# 992                                 Invisibles   2015-01-01                he
# 194                                 Stanley H.   2019-10-13                en
# 977                                   Kwai Boo   2015-08-06                zh
#
#                                    original_title                genre_ids  \
# 42                                       Ad Astra                [18, 878]
# 18                                           1917  [28, 18, 36, 53, 10752]
# 5                                           Joker             [80, 18, 53]
# 6                Star Wars: The Rise of Skywalker            [28, 12, 878]
# 27                                            기생충             [35, 18, 53]
# ..                                            ...                      ...
# 191                  Kral Şakir: Korsanlar Diyarı                 [12, 16]
# 991  Qian ting zong dong yuan 5: shi guang bao he                     [16]
# 992                                        שקופים                       []
# 194                                    Stanley H.             [80, 18, 36]
# 977                                      Kwai Boo                       []
#
#                         backdrop_path  adult  \
# 42   /5BwqwxMEjeFtdknRV792Svo0K1v.jpg  False
# 18   /2lBOQK06tltt8SQaswgb8d657Mv.jpg  False
# 5    /f5F4cRhQdUbyVbB5lTNCwUzD6BP.jpg  False
# 6    /jOzrELAzFxtMx2I4uDGHOotdfsS.jpg  False
# 27   /ApiBzeaa95TNYliSbQ8pJv4Fje7.jpg  False
# ..                                ...    ...
# 191  /r0Eh3XnXecUiJotZJk6fiSrXC1Y.jpg  False
# 991                              None  False
# 992  /y5ASnuC0v6Phn531clzspx2rMAm.jpg  False
# 194  /qcJX63pEuh2M6DwL4BdHPJDhRKp.jpg  False
# 977  /tNXUslT1uXLruOWyPQ5HpQh2BI5.jpg  False
#
#                                               overview  \
# 42   The near future, a time when both hope and har...
# 18   At the height of the First World War, two youn...
# 5    During the 1980s, a failed stand-up comedian i...
# 6    The surviving Resistance faces the First Order...
# 27   All unemployed, Ki-taek's family takes peculia...
# ..                                                 ...
# 191
# 991  Happy Little Submarine Magic Box of Time is a ...
# 992  Newly discharged from the Israeli Army, Ra'ed,...
# 194  The story of one of the most notorious Dutch c...
# 977
#
#                           poster_path
# 42   /xBHvZcjRiWyobQ9kxBhO6B2dtRI.jpg
# 18   /iZf0KyrE25z1sage4SYFLCCrMi9.jpg
# 5    /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg
# 6    /db32LaOibwEliAmSL2jjDF6oDdj.jpg
# 27   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg
# ..                                ...
# 191  /pqt6fjxAvgLVP0wV3FhFcvMfJ0D.jpg
# 991  /klhHM1jmafxI1pBy5ojMGPOjrwa.jpg
# 992  /AmQO3VDv79l6AcvopeRqev0f1yU.jpg
# 194  /mPsR4H8CGvxEPXKVaqWvMsMVNYV.jpg
# 977   /cXC5wRmI3EkrnCF4t5LH0fGcfi.jpg
#
# [1000 rows x 14 columns]

# %%
resp = requests.get('https://api.themoviedb.org/3/genre/movie/list', params=config)
resp_json = resp.json()
genre_list = resp_json['genres']

def genre_mapper(genres):
    genre_container = []
    if not genres:
        return 'None'
    else:
        for genre in genres:
            for x in genre_list:
                if genre == x['id']:
                    genre_container.append(x['name'])
                    
    return genre_container

# %%
# replace genre ids with names
df['genre_mapped_ids'] = df.genre_ids.map(lambda x: genre_mapper(x))

# %%
df.head()
# Out:
#    popularity      id  video  vote_count  vote_average  \
# 0    41.24400  299534  False       13307       8.30000
# 1    63.07200  420818  False        5859       7.20000
# 2    79.61600  330457  False        4625       7.20000
# 3    71.59800  429617  False        7390       7.50000
# 4    46.42900  299537  False        9329       7.00000
#
#                        title release_date original_language  \
# 0          Avengers: Endgame   2019-04-24                en
# 1              The Lion King   2019-07-12                en
# 2                  Frozen II   2019-11-20                en
# 3  Spider-Man: Far from Home   2019-06-28                en
# 4             Captain Marvel   2019-03-06                en
#
#               original_title        genre_ids  \
# 0          Avengers: Endgame    [12, 878, 28]
# 1              The Lion King      [12, 10751]
# 2                  Frozen II  [12, 16, 10751]
# 3  Spider-Man: Far from Home    [28, 12, 878]
# 4             Captain Marvel    [28, 12, 878]
#
#                       backdrop_path  adult  \
# 0  /orjiB3oUIsyz60hoEqkiGpy5CeO.jpg  False
# 1  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg  False
# 2  /xJWPZIYOEFIjZpBL7SVBGnzRYXp.jpg  False
# 3  /5myQbDzw3l8K9yofUXRJ4UTVgam.jpg  False
# 4  /w2PMyoyLU22YvrGK3smVM9fW1jj.jpg  False
#
#                                             overview  \
# 0  After the devastating events of Avengers: Infi...
# 1  Simba idolizes his father, King Mufasa, and ta...
# 2  Elsa, Anna, Kristoff and Olaf head far into th...
# 3  Peter Parker and his friends go on a summer tr...
# 4  The story follows Carol Danvers as she becomes...
#
#                         poster_path                      genre_mapped_ids
# 0  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  [Adventure, Science Fiction, Action]
# 1  /2bXbqYdUdNVa8VIWXVfclP2ICtT.jpg                   [Adventure, Family]
# 2  /pjeMs3yqRmFL3giJy4PMXWZTTPa.jpg        [Adventure, Animation, Family]
# 3   /4q2NNj4S5dG2RLF9CpXsej7yXl.jpg  [Action, Adventure, Science Fiction]
# 4  /AtsgWhDnHTq68L0lLsUrCnM7TjG.jpg  [Action, Adventure, Science Fiction]

# %%
# get fuller movie data

for i, gid in enumerate(df.id):
    resp = requests.get('https://api.themoviedb.org/3/movie/' + str(gid), params=config)
    resp_json = resp.json()
    
    # backfill column data for each movie
    df.at[i, 'revenue'] = resp_json['revenue']
    df.at[i, 'runtime'] = resp_json['runtime']
    df.at[i, 'vote_count'] = resp_json['vote_count']
    df.at[i, 'vote_average'] = resp_json['vote_average']
    df.at[i, 'production_companies'] = resp_json['production_companies']

# %%
df.head()
# Out:
#    popularity      id  video  vote_count  vote_average  \
# 0    41.24400  299534  False       13316       8.30000
# 1    63.07200  420818  False        5865       7.20000
# 2    79.61600  330457  False        4627       7.20000
# 3    71.59800  429617  False        7392       7.60000
# 4    46.42900  299537  False        9335       7.00000
#
#                        title release_date original_language  \
# 0          Avengers: Endgame   2019-04-24                en
# 1              The Lion King   2019-07-12                en
# 2                  Frozen II   2019-11-20                en
# 3  Spider-Man: Far from Home   2019-06-28                en
# 4             Captain Marvel   2019-03-06                en
#
#               original_title        genre_ids  \
# 0          Avengers: Endgame    [12, 878, 28]
# 1              The Lion King      [12, 10751]
# 2                  Frozen II  [12, 16, 10751]
# 3  Spider-Man: Far from Home    [28, 12, 878]
# 4             Captain Marvel    [28, 12, 878]
#
#                       backdrop_path  adult  \
# 0  /orjiB3oUIsyz60hoEqkiGpy5CeO.jpg  False
# 1  /nRXO2SnOA75OsWhNhXstHB8ZmI3.jpg  False
# 2  /xJWPZIYOEFIjZpBL7SVBGnzRYXp.jpg  False
# 3  /5myQbDzw3l8K9yofUXRJ4UTVgam.jpg  False
# 4  /w2PMyoyLU22YvrGK3smVM9fW1jj.jpg  False
#
#                                             overview  \
# 0  After the devastating events of Avengers: Infi...
# 1  Simba idolizes his father, King Mufasa, and ta...
# 2  Elsa, Anna, Kristoff and Olaf head far into th...
# 3  Peter Parker and his friends go on a summer tr...
# 4  The story follows Carol Danvers as she becomes...
#
#                         poster_path                      genre_mapped_ids  \
# 0  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  [Adventure, Science Fiction, Action]
# 1  /2bXbqYdUdNVa8VIWXVfclP2ICtT.jpg                   [Adventure, Family]
# 2  /pjeMs3yqRmFL3giJy4PMXWZTTPa.jpg        [Adventure, Animation, Family]
# 3   /4q2NNj4S5dG2RLF9CpXsej7yXl.jpg  [Action, Adventure, Science Fiction]
# 4  /AtsgWhDnHTq68L0lLsUrCnM7TjG.jpg  [Action, Adventure, Science Fiction]
#
#            revenue   runtime  \
# 0 2797800564.00000 181.00000
# 1 1656943394.00000 118.00000
# 2 1330764959.00000 104.00000
# 3 1131927996.00000 129.00000
# 4 1128274794.00000 124.00000
#
#                                 production_companies
# 0  {'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZx...
# 1  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 2  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...
# 3  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...
# 4  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...

# %%
df.to_pickle('koh_movie_data.pkl')
